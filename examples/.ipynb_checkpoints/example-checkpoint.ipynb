# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join('..', '..')))
from ghostimport.core import activate

# %%
np.random.rand(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 np.random.rand(10)
#
# NameError: name 'np' is not defined

# %%
activate()
# Out:
# ✅ Lazy loader activated!

# %%
np.random.rand(10)
# Out:
# array([0.48350091, 0.03985125, 0.88158786, 0.52742579, 0.11699584,
#        0.92675456, 0.49005563, 0.88107319, 0.0650287 , 0.42772224])
