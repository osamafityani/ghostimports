# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join('..', '..')))
from ghostimport.core import activate

# %%
pd.DataFrame(np.random.rand(10,10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pd.DataFrame(np.random.rand(10,10))
#
# NameError: name 'pd' is not defined

# %%
activate()
# Out:
# Ghost loader activated!

# %%
x = pd.DataFrame(np.random.rand(10,10))
# Out:
# Ghost Module: imported 'pandas' as 'pd'
# Ghost Module: imported 'numpy' as 'np'

# %%
sns.scatterplot(x)
# Out:
# Ghost Module: imported 'seaborn' as 'sns'
# <Axes: >
